# %%
import pandas as pd

df_shops = pd.read_csv(r"C:\Users\srude\Documents\Dev Kram\Gravity_Model_neu\Data\shops_final_564m_21.11.21.csv", encoding='latin-1')
print(df_shops["Year"].unique())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Sandra.Rudeloff\Documents\Dev Kram\Gravity_Model\read_shops.ipynb Cell 1 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Sandra.Rudeloff/Documents/Dev%20Kram/Gravity_Model/read_shops.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/Sandra.Rudeloff/Documents/Dev%20Kram/Gravity_Model/read_shops.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> df_shops = pd.read_csv(r"C:\Users\srude\Documents\Dev Kram\Gravity_Model_neu\Data\shops_final_564m_21.11.21.csv", encoding='latin-1')
#       <a href='vscode-notebook-cell:/c%3A/Users/Sandra.Rudeloff/Documents/Dev%20Kram/Gravity_Model/read_shops.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a> print(df_shops["Year"].unique())
#
# ModuleNotFoundError: No module named 'pandas'

# %%
print(df_shops["City"].unique())
# Out:
# ['Hamburg']

# %%
df_shops_2011 = df_shops[df_shops["Year"] == 2011]
df_shops_2011 = df_shops_2011[['UNIQUEID', 'ID', 'SalesSqMTotal', 'SalesSqMOrganic', 'TotalSales', 'Name', 'Location', 'Address', 'Zip', 'Type', 'TypeAg', 'Size', 'Warehouse', 'Chain','Neighborhood', 'District', 'AreaSqM', 'USERID', 'Income','NEARDIST' ]]
df_shops_2011.rename(columns={'AreaSqM':'NH_AreaSqM', "USERID": 'NH_ID'})
# Drop: LISTID, Time,  TimeLog, Year, City, Country,....
# City = Hamburg, Country = Germany, Time = 2011
# Out:
#       UNIQUEID      ID  SalesSqMTotal  SalesSqMOrganic  TotalSales  \
# 2732    211001  D11001           5450              115     2130950
# 2733    211002  D11002           5450              115     2180000
# 2734    211003  D11003           5450              115     3270000
# 2735    211004  D11004           5450              115     3270000
# 2736    211005  D11005           5450              115     3270000
# ...        ...     ...            ...              ...         ...
# 3221    111036  O11036           5017             5017     3010200
# 3222    111037  O11037           4515             4515      451500
# 3223    111038  O11038           4515             4515     1354500
# 3224    111039  O11039           4515             4515      532770
# 3225    311008  S11008           4112              174      822400
#
#                            Name  Location                    Address    Zip  \
# 2732                       Aldi       412             Hermannstal 72  22119
# ...

# %%
df_shops_2011.to_csv(r'C:\Users\srude\Documents\Dev Kram\Gravity_Model_neu\Output_csv_shops\Hamburg_shops_2011.csv', index=False )
